# %%
from IPython.display import clear_output
! pip install alphagenome
clear_output()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# sample_data

# %%
from io import StringIO
from alphagenome import colab_utils
from alphagenome.data import genome
from alphagenome.models import dna_client, variant_scorers
from google.colab import data_table, files
import pandas as pd
from tqdm import tqdm

data_table.enable_dataframe_formatter()

# Load the model.
dna_model = dna_client.create(colab_utils.get_api_key())

# %%
# @title Score batch of variants.

# # Load VCF file containing variants.
# vcf_file = 'placeholder'  # @param

# # We provide an example list of variants to illustrate.
# vcf_file = """variant_id\tCHROM\tPOS\tREF\tALT
# chr3_58394738_A_T_b38\tchr3\t58394738\tA\tT
# chr8_28520_G_C_b38\tchr8\t28520\tG\tC
# chr16_636337_G_A_b38\tchr16\t636337\tG\tA
# chr16_1135446_G_T_b38\tchr16\t1135446\tG\tT
# """

vcf = pd.read_csv('/content/drive/MyDrive/AlphaGenome/K562_var2grn_pip70_alphagenome_format.tsv', sep='\t')
# vcf = vcf.iloc[1000:]
required_columns = ['variant_id', 'CHROM', 'POS', 'REF', 'ALT']
for column in required_columns:
  if column not in vcf.columns:
    raise ValueError(f'VCF file is missing required column: {column}.')

organism = 'human'  # @param ["human", "mouse"] {type:"string"}

# @markdown Specify length of sequence around variants to predict:
sequence_length = '1MB'  # @param ["2KB", "16KB", "100KB", "500KB", "1MB"] { type:"string" }
sequence_length = dna_client.SUPPORTED_SEQUENCE_LENGTHS[
    f'SEQUENCE_LENGTH_{sequence_length}'
]

# %%
vcf
# Out:
#                  variant_id  CHROM        POS REF ALT
# 0     chr6_41957260_C_T_b38   chr6   41957260   C   T
# 1    chr4_144104973_C_T_b38   chr4  144104973   C   T
# 2     chr5_88884379_T_C_b38   chr5   88884379   T   C
# 3    chr11_62042222_T_C_b38  chr11   62042222   T   C
# 4     chr4_54571325_T_C_b38   chr4   54571325   T   C
# 5    chr1_231421418_C_G_b38   chr1  231421418   C   G
# 6     chr8_21960657_T_C_b38   chr8   21960657   T   C
# 7      chr2_8645073_A_C_b38   chr2    8645073   A   C
# 8    chr17_78014040_C_T_b38  chr17   78014040   C   T
# 9    chr5_136082636_C_A_b38   chr5  136082636   C   A
# 10   chr1_231422308_G_C_b38   chr1  231422308   G   C
# 11   chr11_72041114_T_G_b38  chr11   72041114   T   G
# 12   chr10_69392716_C_T_b38  chr10   69392716   C   T
# 13   chr19_17999765_G_A_b38  chr19   17999765   G   A
# 14   chr15_66630557_C_G_b38  chr15   66630557   C   G
# 15  chr12_131949846_G_T_b38  chr12  131949846   G   T
# 16    chr5_34656370_G_A_b38   chr5   34656370   G   A
# 17   chr3_179148135_G_A_b38   chr3  179148135   G   A
# 18   chr12_77065684_C_T_b38  chr12   77065684   C   T
# 19   chr20_44210535_T_C_b38  chr20   44210535   T   C
# 20  chr12_111599646_G_A_b38  chr12  111599646   G   A
# 21    chr18_9914839_G_C_b38  chr18    9914839   G   C
# 22    chr6_33272092_C_T_b38   chr6   33272092   C   T
# 23    chr3_72996737_G_A_b38   chr3   72996737   G   A
# 24   chr1_230978849_C_T_b38   chr1  230978849   C   T
# 25    chr7_87475843_A_G_b38   chr7   87475843   A   G
# 26   chr4_139084424_G_A_b38   chr4  139084424   G   A
# 27   chr17_64506317_A_G_b38  chr17   64506317   A   G
# 28   chr19_18419407_A_C_b38  chr19   18419407   A   C
# 29   chr13_75481466_G_A_b38  chr13   75481466   G   A

# %%
# @markdown Specify which scorers to use to score your variants:
score_rna_seq = True  # @param { type: "boolean"}
score_cage = True  # @param { type: "boolean" }
score_procap = True  # @param { type: "boolean" }
score_atac = True  # @param { type: "boolean" }
score_dnase = True  # @param { type: "boolean" }
score_chip_histone = True  # @param { type: "boolean" }
score_chip_tf = True  # @param { type: "boolean" }
score_polyadenylation = True  # @param { type: "boolean" }
score_splice_sites = True  # @param { type: "boolean" }
score_splice_site_usage = True  # @param { type: "boolean" }
score_splice_junctions = True  # @param { type: "boolean" }

# @markdown Other settings:
download_predictions = False  # @param { type: "boolean" }

# Parse organism specification.
organism_map = {
    'human': dna_client.Organism.HOMO_SAPIENS,
    'mouse': dna_client.Organism.MUS_MUSCULUS,
}
organism = organism_map[organism]

# Parse scorer specification.
scorer_selections = {
    'rna_seq': score_rna_seq,
    'cage': score_cage,
    'procap': score_procap,
    'atac': score_atac,
    'dnase': score_dnase,
    'chip_histone': score_chip_histone,
    'chip_tf': score_chip_tf,
    'polyadenylation': score_polyadenylation,
    'splice_sites': score_splice_sites,
    'splice_site_usage': score_splice_site_usage,
    'splice_junctions': score_splice_junctions,
}

all_scorers = variant_scorers.RECOMMENDED_VARIANT_SCORERS
selected_scorers = [
    all_scorers[key]
    for key in all_scorers
    if scorer_selections.get(key.lower(), False)
]

# Remove any scorers or output types that are not supported for the chosen organism.
unsupported_scorers = [
    scorer
    for scorer in selected_scorers
    if (
        organism.value
        not in variant_scorers.SUPPORTED_ORGANISMS[scorer.base_variant_scorer]
    )
    | (
        (scorer.requested_output == dna_client.OutputType.PROCAP)
        & (organism == dna_client.Organism.MUS_MUSCULUS)
    )
]
if len(unsupported_scorers) > 0:
  print(
      f'Excluding {unsupported_scorers} scorers as they are not supported for'
      f' {organism}.'
  )
  for unsupported_scorer in unsupported_scorers:
    selected_scorers.remove(unsupported_scorer)


# Score variants in the VCF file.
results = []

for i, vcf_row in tqdm(vcf.iterrows(), total=len(vcf)):
  variant = genome.Variant(
      chromosome=str(vcf_row.CHROM),
      position=int(vcf_row.POS),
      reference_bases=vcf_row.REF,
      alternate_bases=vcf_row.ALT,
      name=vcf_row.variant_id,
  )
  interval = variant.reference_interval.resize(sequence_length)

  variant_scores = dna_model.score_variant(
      interval=interval,
      variant=variant,
      variant_scorers=selected_scorers,
      organism=organism,
  )
  results.append(variant_scores)

df_scores = variant_scorers.tidy_scores(results)

if download_predictions:
  df_scores.to_csv('variant_scores.csv', index=False)
  files.download('variant_scores.csv')

# df_scores
# Out:
# 100%|██████████| 30/30 [01:15<00:00,  2.51s/it]

# %%
df_scores['variant_id'].astype(str).nunique(), len(df_scores)
# Out:
# (30, 621982)

# %%
# df_scores['variant_id'].astype(str).nunique()

# %%
df_scores.to_csv('/content/drive/MyDrive/AlphaGenome/alphagenome_score/K562_var2grn_pip70_alphagenome_score.tsv', sep='\t', index=False)

# %%
df_scores['variant_id'] = df_scores['variant_id'].astype(str)

# %%
df_scores# .head()
# Out:
# Warning: total number of rows (621982) exceeds max_rows (20000). Falling back to pandas display.
#                 variant_id            scored_interval          gene_id  \
# 0        chr6:41957260:C>T   chr6:41432972-42481548:.             None
# 1        chr6:41957260:C>T   chr6:41432972-42481548:.             None
# 2        chr6:41957260:C>T   chr6:41432972-42481548:.             None
# 3        chr6:41957260:C>T   chr6:41432972-42481548:.             None
# 4        chr6:41957260:C>T   chr6:41432972-42481548:.             None
# ...                    ...                        ...              ...
# 621977  chr13:75481466:G>A  chr13:74957178-76005754:.  ENSG00000136111
# 621978  chr13:75481466:G>A  chr13:74957178-76005754:.  ENSG00000136111
# 621979  chr13:75481466:G>A  chr13:74957178-76005754:.  ENSG00000136111
# 621980  chr13:75481466:G>A  chr13:74957178-76005754:.  ENSG00000136111
# 621981  chr13:75481466:G>A  chr13:74957178-76005754:.  ENSG00000136111
#
#        gene_name       gene_type gene_strand junction_Start junction_End  \
# 0           None            None        None           None         None
# 1           None            None        None           None         None
# 2           None            None        None           None         None
# 3           None            None        None           None         None
# 4           None            None        None           None         None
# ...          ...             ...         ...            ...          ...
# 621977    TBC1D4  protein_coding           -           None         None
# 621978    TBC1D4  protein_coding           -           None         None
# 621979    TBC1D4  protein_coding           -           None         None
# 621980    TBC1D4  protein_coding           -           None         None
# 621981    TBC1D4  protein_coding           -           None         None
#
#        output_type                                     variant_scorer  ...  \
# 0             ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 1             ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 2             ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 3             ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 4             ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# ...            ...                                                ...  ...
# 621977     RNA_SEQ                            PolyadenylationScorer()  ...
# 621978     RNA_SEQ                            PolyadenylationScorer()  ...
# 621979     RNA_SEQ                            PolyadenylationScorer()  ...
# 621980     RNA_SEQ                            PolyadenylationScorer()  ...
# 621981     RNA_SEQ                            PolyadenylationScorer()  ...
#
#        track_strand         Assay title  ontology_curie  \
# 0                 .            ATAC-seq      CL:0000084
# 1                 .            ATAC-seq      CL:0000100
# 2                 .            ATAC-seq      CL:0000236
# 3                 .            ATAC-seq      CL:0000623
# 4                 .            ATAC-seq      CL:0000624
# ...             ...                 ...             ...
# 621977            .  polyA plus RNA-seq  UBERON:0018115
# 621978            .  polyA plus RNA-seq  UBERON:0018116
# 621979            .  polyA plus RNA-seq  UBERON:0018117
# 621980            .  polyA plus RNA-seq  UBERON:0018118
# 621981            .  polyA plus RNA-seq  UBERON:0036149
#
#                          biosample_name                 biosample_type  \
# 0                                T-cell                   primary_cell
# 1                          motor neuron  in_vitro_differentiated_cells
# 2                                B cell                   primary_cell
# 3                   natural killer cell                   primary_cell
# 4       CD4-positive, alpha-beta T cell                   primary_cell
# ...                                 ...                            ...
# 621977                left renal pelvis                         tissue
# 621978               right renal pelvis                         tissue
# 621979   left renal cortex interstitium                         tissue
# 621980  right renal cortex interstitium                         tissue
# 621981                  suprapubic skin                         tissue
#
#        transcription_factor histone_mark                      gtex_tissue  \
# 0                       NaN          NaN                              NaN
# 1                       NaN          NaN                              NaN
# 2                       NaN          NaN                              NaN
# 3                       NaN          NaN                              NaN
# 4                       NaN          NaN                              NaN
# ...                     ...          ...                              ...
# 621977                  NaN          NaN
# 621978                  NaN          NaN
# 621979                  NaN          NaN
# 621980                  NaN          NaN
# 621981                  NaN          NaN  Skin_Not_Sun_Exposed_Suprapubic
#
#        raw_score  quantile_score
# 0      -0.031329       -0.811199
# 1      -0.247378       -0.972376
# 2      -0.082275       -0.934881
# 3      -0.112340       -0.981678
# 4      -0.045804       -0.862638
# ...          ...             ...
# 621977  0.003811        0.751654
# 621978  0.002566        0.563110
# 621979  0.003187        0.686638
# 621980  0.004605        0.788366
# 621981  0.005154        0.846489
#
# [621982 rows x 21 columns]

# %%
# df_scores[df_scores['variant_id'] == 'chr3:58394738:A>T'][['output_type', 'biosample_name', 'raw_score']]
# Out:
# Warning: total number of rows (20329) exceeds max_rows (20000). Falling back to pandas display.
#       output_type                   biosample_name  raw_score
# 0            ATAC                           T-cell  -0.003778
# 1            ATAC                     motor neuron   0.012303
# 2            ATAC                           B cell  -0.000334
# 3            ATAC              natural killer cell  -0.009233
# 4            ATAC  CD4-positive, alpha-beta T cell  -0.010510
# ...           ...                              ...        ...
# 20324     RNA_SEQ                left renal pelvis   0.000705
# 20325     RNA_SEQ               right renal pelvis   0.002350
# 20326     RNA_SEQ   left renal cortex interstitium   0.001645
# 20327     RNA_SEQ  right renal cortex interstitium   0.002350
# 20328     RNA_SEQ                  suprapubic skin   0.001175
#
# [20329 rows x 3 columns]

# %%
print(vcf_file)
# Out:
# variant_id	CHROM	POS	REF	ALT
# chr3_58394738_A_T_b38	chr3	58394738	A	T
# chr8_28520_G_C_b38	chr8	28520	G	C
# chr16_636337_G_A_b38	chr16	636337	G	A
# chr16_1135446_G_T_b38	chr16	1135446	G	T

# %%
df_scores['variant_id'].unique()
# Out:
# array(['chr3:58394738:A>T', 'chr8:28520:G>C', 'chr16:636337:G>A',
#        'chr16:1135446:G>T'], dtype=object)
